# %% [markdown]
# <a href="https://colab.research.google.com/github/anujsonkar1526-coder/Data-Science-class-notes/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello world")
# Out:
# hello world

# %%
print("hello machine")
# Out:
# hello machine

# %%
a=10
print(a*2)
# Out:
# 20

# %%
a=10
b=20
c=30
d=40
e=50
print(a+b+c+d+e)
# Out:
# 150

# %%
a=input()
b=input()
print(a+b)
# Out:
# 2
# 3
# 23

# %%
a=int(input())
b=int(input())
print(a+b+e)
# Out:
# 2
# 3
# 55

# %%
a=1
b=2
c=a
a=b
b=c
print(a, b)
# Out:
# 2 1

# %%
a=10
b=20
a=a^b
b=a^b
a=a^b
print(a, b)
# Out:
# 20 10

# %%
n=int(input())
for i in range(1,n):
  if(i%2==0):
     print("even=",i)
  else:
    print("odd=", i)
# Out:
# 4
# odd= 1
# even= 2
# odd= 3

# %%
a=int(input())
if(a>0):
  print("positiv")
elif(a==0):
  print("zero")
else:
  print("negative")

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
a=str(input())

if(a=="sun"):
  print("sunday")
elif(a=="mon"):
  print("monday")
elif(a=="tues"):
  print("tuesday")
elif(a=="wed"):
  print("wednesday")
elif(a=="thus"):
  print("thusday")
elif(a=="fri"):
  print("friday")
else:
  print("saturday")

# %%
for i in range (10):
 print(i)

# %%
for i in range(start=1, end=n, step(gap)=1):

# %%
a=0
while(a<10):
  print(a)
  a=a+1

# %%
a="anujsonkar"
b=len(a)
print(b)
